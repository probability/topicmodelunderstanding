# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from imports import *
from hotstepper.Utils import Utils
import operator
from datetime import datetime, timedelta
import staircase as sc
# %matplotlib inline

import warnings
warnings.filterwarnings("ignore")

# %%
s1 = Step(end=pd.Timestamp(2020,1,1),weight=3)
ax = s1.plot()

p = np.arange(pd.Timestamp(2019,12,31),pd.Timestamp(2020,1,2),pd.Timedelta(minutes=1)).astype(pd.Timestamp)
t = np.asarray(list(map(Utils.get_ts, p)),dtype=float)
x = Bases.fflogit(t,np.array([[(pd.Timestamp(2020,1,1)).timestamp(),-1,3]]),25000)
ax.step(p,x,color='g')
#s1.smooth_plot(ax=ax,smooth_factor=250000,ts_grain=pd.Timedelta(minutes=1),color='g')

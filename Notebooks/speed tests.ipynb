# %%
from imports import *
import staircase as sc
# %matplotlib inline
import operator
import warnings
warnings.filterwarnings("ignore")
import hotstepper.fastbase as fb

# %%
s = Step(start = 100.0,weight=3.0)
s.plot()
# Out:
# <AxesSubplot:>

# %%
t = np.arange(-1000,5000,0.01)

# %%
len(t)

# %%
# %%timeit -r 10 -n 10
s.step(t)
# Out:
# 5.17 ms ± 521 µs per loop (mean ± std. dev. of 10 runs, 10 loops each)

# %%
# %%timeit -r 10 -n 10
s.stepf(t)

# %%
fig,ax = plt.subplots(figsize=(32,6))

ax.step(t,s.step(t),color='g')
#ax.step(t,s.step_old(t),color='r')

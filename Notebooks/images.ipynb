# %%
import matplotlib.pyplot as plt
from imports import *
import staircase as sc

# %%
st = Steps().add([Step(2),Step(1),Step(2),Step(3),Step(5),Step(8)])
ax = st.plot()

fig = ax.figure
fig.savefig('fibo_steps.png')
